# %%
import pandas as pd
import numpy as np
data = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')

# %%
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
data.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
# Create a barplot of the number of customers per Gender.
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
gender_plot = sns.countplot(x='Gender', data=data, palette='viridis')
plt.title('Number of Customers per Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Customers')

# Counting on top of the bars
for p in gender_plot.patches:
    gender_plot.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                         ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.show()

# %%
# Create a barplot of the number of customers per EmploymentStatus and Gender.
plt.figure(figsize=(12, 8))
employment_gender_plot = sns.countplot(x='EmploymentStatus', hue='Gender', data=data, palette='pastel')
plt.title('Number of Customers per EmploymentStatus and Gender')
plt.xlabel('EmploymentStatus')
plt.ylabel('Number of Customers')

# Display the counts on top of the bars
for p in employment_gender_plot.patches:
    employment_gender_plot.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                                    ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.legend(title='Gender')
plt.show()

# %%
# Identify Measurements (quantitative) and Dimensions(categorical). Are they the same as the ones in your Pandas dataframe? Modify accordingly.
measurements = ['Customer Lifetime Value', 'Income', 'Monthly Premium Auto', 'Total Claim Amount', 'Number of Policies']
dimensions = ['Gender', 'EmploymentStatus', 'Marital Status', 'Education']

# %%
measurements = data.select_dtypes(include=['float64', 'int64']).columns.tolist()
dimensions = data.select_dtypes(include=['object']).columns.tolist()

print("Measurements:", measurements)
print("Dimensions:", dimensions)
# Out:
# Measurements: ['Customer Lifetime Value', 'Income', 'Monthly Premium Auto', 'Months Since Last Claim', 'Months Since Policy Inception', 'Number of Open Complaints', 'Number of Policies', 'Total Claim Amount']
# Dimensions: ['Customer', 'State', 'Response', 'Coverage', 'Education', 'Effective To Date', 'EmploymentStatus', 'Gender', 'Location Code', 'Marital Status', 'Policy Type', 'Policy', 'Renew Offer Type', 'Sales Channel', 'Vehicle Class', 'Vehicle Size']

# %%
#saved notebook as unit-4-lab.tbwx
